# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import cv2

# %%
dataset="Train"

# %%
images=os.listdir("Train/Images/")
len(images)
# Out:
# 304

# %%
train=pd.read_csv("Train/train.csv")

# %%
pokemon=train["NameOfPokemon"].unique()
# Out:
# array(['Pikachu', 'Bulbasaur', 'Charmander'], dtype=object)

# %%
dic={
    0:"Pikachu",
    1:"Bulbasaur",
    2:"Charmander"
}
reverse_dic={
    "Pikachu":0,
    "Bulbasaur":1,
    "Charmander":2
}

# %%
X=[]
Y=[]
im_path="Train/Images/"
for im in images:
    img=cv2.imread(im_path+im)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img=cv2.resize(img,(100,100))
    X.append(img)
    lab=reverse_dic[list(train[train["ImageId"]==im]["NameOfPokemon"])[0]]
    Y.append(lab)

# %%
X=np.array(X)
Y=np.array(Y)

# %%
X.shape
# Out:
# (304, 100, 100, 3)

# %%
i=plt.imread(im_path+images[300])
plt.imshow(i)

# %%
train
# Out:
#      ImageId NameOfPokemon
# 0    296.jpg       Pikachu
# 1    297.jpg       Pikachu
# 2    298.jpg       Pikachu
# 3    299.jpg       Pikachu
# 4    300.jpg       Pikachu
# 5    301.jpg       Pikachu
# 6    302.jpg       Pikachu
# 7    303.jpg       Pikachu
# 8    304.jpg       Pikachu
# 9    305.jpg       Pikachu
# 10   306.jpg       Pikachu
# 11   307.jpg       Pikachu
# 12   308.jpg       Pikachu
# 13   309.jpg       Pikachu
# 14   310.jpg       Pikachu
# 15   311.jpg       Pikachu
# 16   312.jpg       Pikachu
# 17   313.jpg       Pikachu
# 18   314.jpg       Pikachu
# 19   315.jpg       Pikachu
# 20   316.jpg       Pikachu
# 21   317.jpg       Pikachu
# 22   318.jpg       Pikachu
# 23   319.jpg       Pikachu
# 24   320.jpg       Pikachu
# 25   321.jpg       Pikachu
# 26   322.jpg       Pikachu
# 27   323.jpg       Pikachu
# 28   324.jpg       Pikachu
# 29   325.jpg       Pikachu
# ..       ...           ...
# 274  591.jpg    Charmander
# 275  592.jpg    Charmander
# 276  593.jpg    Charmander
# 277  594.jpg    Charmander
# 278  595.jpg    Charmander
# 279  596.jpg    Charmander
# 280  597.jpg    Charmander
# 281  598.jpg    Charmander
# 282  599.jpg    Charmander
# 283  600.jpg    Charmander
# 284  601.jpg    Charmander
# 285  602.jpg    Charmander
# 286  603.jpg    Charmander
# 287  604.jpg    Charmander
# 288  605.jpg    Charmander
# 289  606.jpg    Charmander
# 290  607.jpg    Charmander
# 291  608.jpg    Charmander
# 292  609.jpg    Charmander
# 293  610.jpg    Charmander
# 294  611.jpg    Charmander
# 295  612.jpg    Charmander
# 296  613.jpg    Charmander
# 297  614.jpg    Charmander
# 298  615.jpg    Charmander
# 299  616.jpg    Charmander
# 300  617.jpg    Charmander
# 301  618.jpg    Charmander
# 302  619.jpg    Charmander
# 303  620.jpg    Charmander
#
# [304 rows x 2 columns]

# %%
imgt=images[np.random.randint(304)]

testing=cv2.imread(im_path+imgt)
testing=cv2.resize(testing,(100,100))
plt.imshow(testing)

# %%
def dist(v1,v2):#point can be n dimension
    return np.sqrt(np.sum((v1-v2)**2))
def knn(X,Y,query_point,k=5):
    m=X.shape[0]
    distances=[]
    for i in range(m):
        distances.append((dist(query_point,X[i]),Y[i]))
        
    distances=sorted(distances)[:5]
    distances=np.array(distances)
    labels=distances[:,1]
    labels,freq=np.unique(labels,return_counts=True)
    pred=labels[freq.argmax()]
    
    return dic[pred]

# %%
knn(X,Y,testing)
# Out:
# 'Pikachu'

# %%
reverse_dic[list(train[train["ImageId"]==imgt]["NameOfPokemon"])[0]]
# Out:
# 0
